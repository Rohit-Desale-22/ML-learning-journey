# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### ✅ Check Current Working Directory
# Shows the current folder where Python is operating.
# Useful to know where Python is looking for files.
# Python’s current working directory may be different from the terminal’s directory

# %%
import os
print(os.getcwd())
# Out:
# d:\ML-learning-journey\projects\Placement_Prediction_Project

# %% [markdown]
# ### 🔄 Change the Working Directory

# %%
os.chdir("d:\ML-learning-journey\data-science-fundamentals")
print(os.getcwd())
os.chdir("d:\ML-learning-journey")
print(os.getcwd())
# Out:
# d:\ML-learning-journey\data-science-fundamentals
# d:\ML-learning-journey

# %% [markdown]
# ### 📁 3. Check if File/Folder Exists

# %%
# ✅ Option 1: Using raw string
print(os.path.exists(r"data-science-fundamentals\data_files\placement.csv"))

# ✅ Option 2: Using forward slashes
print(os.path.exists("data-science-fundamentals/data_files/placement.csv"))

# ✅ Option 3: Using os.path.join (cross-platform)
path = os.path.join("data-science-fundamentals", "data_files", "placement.csv")
print(os.path.exists(path))
# Out:
# True
# True
# True

# %%
df = pd.read_csv("data-science-fundamentals/data_files/placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# # 🧹 Preprocessing + EDA + Feature Selection

# %%
df.info()

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c = df['placement'])

# %% [markdown]
# # Train Test Split

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,2:3]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 71   6.1  132.0
# 64   7.0   64.0
# 44   7.5   61.0
# 68   4.0   75.0
# 97   6.7  182.0
# ..   ...    ...
# 16   5.2  224.0
# 32   7.0  139.0
# 31   3.9  109.0
# 46   5.3  114.0
# 25   5.0   91.0
#
# [90 rows x 2 columns]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train # X_train is now an array
# Out:
# array([[ 0.10274116,  0.16402555],
#        [ 0.88783869, -1.56672679],
#        [ 1.32400398, -1.64308352],
#        [-1.72915307, -1.28675215],
#        [ 0.62613951,  1.43663757],
#        [-2.33978448,  1.46208981],
#        [ 1.14953786, -1.00677751],
#        [ 0.88783869,  1.25847188],
#        [ 0.0155081 , -0.03959237],
#        [ 1.41123704, -0.93042079],
#        [ 2.19633457, -0.14140134],
#        [ 0.71337257, -0.34501926],
#        [ 1.41123704,  0.06221659],
#        [ 0.36444033, -0.2432103 ],
#        [-0.94405555,  0.64761812],
#        [-0.76958943,  1.28392412],
#        [-0.68235637, -0.90496855],
#        [-0.76958943, -1.51582231],
#        [-2.16531837,  2.73470182],
#        [ 0.45167339,  0.87668828],
#        [ 1.32400398,  0.8257838 ],
#        [-0.94405555,  0.21493003],
#        [-1.11852166, -0.11594909],
#        [ 1.76016927, -1.18494319],
#        [ 0.71337257, -0.06504461],
#        [-0.85682249, -1.59217903],
#        [-0.59512331, -0.11594909],
# ...

# %%
X_test = scaler.transform(X_test) # X_test is an array

# %% [markdown]
# # Training Data

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# d:\ML-learning-journey\.venv\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_train
# Out:
#     placement
# 71          1
# 64          1
# 44          1
# 68          0
# 97          1
# ..        ...
# 16          0
# 32          1
# 31          0
# 46          0
# 25          0
#
# [90 rows x 1 columns]

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
#     placement
# 20          1
# 98          1
# 77          1
# 54          1
# 76          0
# 81          0
# 65          1
# 94          0
# 73          0
# 14          0

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values.ravel(),clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
print(os.getcwd())

# %%
print(os.listdir('projects'))

# %%
os.chdir('projects/placement_prediction_project.ipynb')

# %%
import shutil

# %%
os.mkdir('projects/Placement_Prediction_Project')

# %%
shutil.move("projects/placement_prediction_project.ipynb","projects/Placement_Prediction_Project")

# %%
os.chdir('projects/Placement_Prediction_Project')

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %% [markdown]
# # Deploying this model
# yet to be learned.....
